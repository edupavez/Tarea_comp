# %%
import numpy as np
import matplotlib as plt
from matplotlib import pyplot as pyp
import pandas as pd

# %%
pd.read_csv("P1grupo_8.csv")
# Out:
#          x          y
# 0    0.019   1.774182
# 1    0.022   5.866850
# 2    0.025   2.716214
# 3    0.029   8.123620
# 4    0.031   4.679515
# ..     ...        ...
# 995  9.954  31.658958
# 996  9.962  31.354353
# 997  9.980  36.735163
# 998  9.989  31.194713
# 999  9.994  40.820600
#
# [1000 rows x 2 columns]

# %%
puntos = list()

with open("P1grupo_8.csv", "r") as archivo:
    contenido = archivo.readlines()[1:]
    for linea in contenido:
        linea = linea.rstrip("\n")
        linea = linea.split(",")
        x = float(linea[0])
        y = float(linea[1])
        puntos.append((x,y))

# %%
fig, ax = pyp.subplots(1, 1, figsize = (12, 12))
#ax.set_facecolor("black")
ax.grid = True

for punto in puntos:
    x = punto[0]
    y = punto[1]
    ax.scatter(x, y, marker = "o", color = "blue")
